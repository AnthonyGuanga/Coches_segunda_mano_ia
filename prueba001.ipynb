# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Cars_Data_6k.csv")
data.head()
# Out:
#    Unnamed: 0    Brand            Name Sticker    Year       KM      Fuel  \
# 0           0     Opel      Opel Corsa       C  2022.0  47707.0    Diésel
# 1           1  Peugeot  Peugeot Rifter       C  2019.0  57194.0    Diésel
# 2           2  Renault  Renault Kadjar       C  2017.0  66428.0    Diésel
# 3           3    Dacia   Dacia Sandero       C  2016.0  48430.0  Gasolina
# 4           4   Nissan  Nissan QASHQAI       C  2020.0  72209.0  Gasolina
#
#       CV Transmission One_owner  ...  Weight   Trunk  Tank   Vmax  0to100  \
# 0  102.0       MANUAL      True  ...  1165.0     NaN     -  188.0    10.2
# 1  130.0         AUTO      True  ...  1430.0  1355.0     -  179.0     4.3
# 2  110.0       MANUAL     False  ...  1380.0  1478.0     -  182.0    11.9
# 3   75.0       MANUAL      True  ...   941.0  1200.0     -  162.0    14.5
# 4  160.0         AUTO     False  ...  1315.0  1598.0     -  198.0     9.9
#
#    Consumption Emissions  Keys_num  Extras_num    Price
# 0          4.1     107.0       1.0         5.0  15700.0
# 1        114.0       NaN       2.0         5.0  24900.0
# 2          3.8      99.0       2.0         5.0  17800.0
# 3          5.8     130.0       2.0         3.0   9300.0
# 4          6.9     156.0       2.0         5.0  21500.0
#
# [5 rows x 24 columns]

# %%
data.shape
# Out:
# (5980, 24)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5980 entries, 0 to 5979
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    5980 non-null   int64
#  1   Brand         5973 non-null   object
#  2   Name          5973 non-null   object
#  3   Sticker       5948 non-null   object
#  4   Year          5973 non-null   float64
#  5   KM            5973 non-null   float64
#  6   Fuel          5973 non-null   object
#  7   CV            5973 non-null   float64
#  8   Transmission  5973 non-null   object
#  9   One_owner     5973 non-null   object
#  10  Location      4841 non-null   object
#  11  Length        5973 non-null   float64
#  12  Width         5964 non-null   float64
#  13  Height        5969 non-null   float64
#  14  Weight        5953 non-null   float64
#  15  Trunk         4613 non-null   float64
#  16  Tank          5973 non-null   object
#  17  Vmax          5815 non-null   float64
#  18  0to100        5947 non-null   float64
#  19  Consumption   5791 non-null   float64
#  20  Emissions     5094 non-null   float64
#  21  Keys_num      5973 non-null   float64
#  22  Extras_num    5973 non-null   float64
#  23  Price         5973 non-null   float64
# dtypes: float64(15), int64(1), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Comprobación de valores únicos

# %%
data['Brand'].unique()
# Out:
# array(['Opel', 'Peugeot', 'Renault', 'Dacia', 'Nissan', 'BMW', 'KIA',
#        'Volkswagen', 'Land Rover', 'Skoda', 'Hyundai', 'Mercedes', 'Ford',
#        'Seat', 'Honda', 'Audi', 'Mazda', 'Volvo', 'Citroën', 'Toyota',
#        'Mini', 'Suzuki', 'Fiat', 'Cupra', 'Jeep', 'Chevrolet', 'Lexus',
#        'Mitsubishi', 'Infiniti', 'SsangYong', 'BYD', 'DS', 'RIMOR',
#        'Iveco', 'Porsche', 'Alfa Romeo', 'Jaguar', 'Smart', 'Tesla',
#        'Subaru', 'MG', 'XEV', 'DFSK', 'Abarth', nan], dtype=object)

# %%
data['Year'].unique()
# Out:
# array([2022., 2019., 2017., 2016., 2020., 2018., 2015., 2021., 2013.,
#        2011., 2014., 2023., 2012., 2006., 2010., 2008., 2005., 2009.,
#        2004., 2007., 2024., 2002., 2003., 2000.,   nan])

# %%
data['Price'].unique()
# Out:
# array([15700., 24900., 17800.,  9300., 21500., 20900., 15690., 13500.,
#        23800., 37900., 14450., 26990., 27800., 34300., 14990., 19250.,
#         9750., 23900., 12300., 19990., 15490., 12990.,  8990., 24990.,
#        21490., 16500., 18200., 21652., 22790., 15200., 16990., 25590.,
#        12950., 19590., 10200., 11900., 16490., 15900., 15750., 27990.,
#        23700., 15990., 15800., 14400., 20300., 29450., 11990., 12800.,
#         8200., 25800., 34800., 15082., 26900., 21990., 13250., 22900.,
#        17500., 10450., 18553., 39500., 19500., 22490., 13400., 13990.,
#        18500., 10390., 13190., 12390., 13390., 30900., 14500., 20495.,
#         4450., 12450.,  6300., 14350.,  3500., 20490., 11250., 57900.,
#         2900., 15500., 21950.,  9500., 26500., 29890., 12500., 16300.,
#        44500., 28490., 16200., 24338., 15619.,  8950., 46950., 20867.,
#         4900., 16450., 14300., 20250.,  3900., 18900., 17400., 21900.,
#        20700., 15400.,  7350., 20450.,  7750., 16800., 23290.,  9990.,
#        32500.,  9800., 11390., 46500.,  9590.,  4500., 15950.,  9450.,
#         2500., 24790., 22990., 12900., 25990., 17300., 17990.,  3800.,
#        10900.,  5350.,  5900., 11350., 21390.,  8750., 12750.,  8500.,
#        11650.,  7250., 34900.,  8900., 22800., 20590., 37500., 13900.,
#        14900., 13800., 22300., 14850., 48790., 12700., 19256., 16700.,
#        10850., 34990.,  8150., 27250., 26750., 23990., 13750., 26700.,
#        14750., 15300., 33500., 18950., 25900., 11800., 18990., 21350.,
#        29750., 34500., 10990.,  5750., 13850., 24300., 24214., 28350.,
#        31800., 22438., 14800., 17390., 25165., 20041., 27650., 23016.,
#        53990.,  8512., 23500., 19800., 10750.,  7300., 28990., 20890.,
#        17900., 22231., 10082., 10661., 12933., 20990., 22500., 11561.,
#        14790., 17850., 15680., 19750., 22450., 17450.,  6900., 12603.,
#        25500., 21790., 15537., 17200., 16350.,  7400., 14250.,  8450.,
#        19200., 13450., 16390.,  9338., 14490., 29500., 14710., 14390.,
#        18800., 28090., 21800., 15450.,  9900., 17272.,  6890., 20800.,
#        18925., 14200., 19450.,  7990., 11500., 28800., 40200., 11450.,
#        10350., 61990., 11890., 14290., 18250.,  9850., 13090.,  6990.,
#        11280., 14700., 32975.,  8490.,  8800., 34236., 14150., 21300.,
#         7700., 24800., 40800., 12600., 19490., 11983., 27190., 28700.,
#        16033., 18099., 32990., 16280., 29900., 27490., 36300., 41800.,
#        13966.,  6500.,  7900., 39800., 17190., 11490.,  9400.,  7800.,
#        10500., 16190., 17700., 18760., 25390., 16900.,  8290., 12644.,
#        44990., 12685., 24500., 10650., 13553., 17603.,  4850., 50826.,
#        18842., 25600.,  5800., 13200.,  8719., 13719., 15190., 25200.,
#        45900., 22975.,  9669., 13140., 29490.,  7450., 16322., 20371.,
#        13890., 19900., 18490., 22740., 10800., 18140., 14690., 16290.,
#        28500., 13290., 26490.,  7500., 25190., 49890., 21322., 14890.,
#        15180., 11400., 18290., 23300., 12809.,  9700., 40990., 20190.,
#        25490., 16250., 31490., 21200., 10330., 22520.,  8690., 22479.,
#        16446., 10247., 18300., 36990., 23512., 18512.,  6690., 18966.,
#        26033., 20165., 21280., 19173., 12890., 21033., 11200., 11074.,
#        45990., 15780., 16301., 10290., 22892., 22190., 12314., 17727.,
#        25700., 23710.,  3600., 21404.,  5190., 18173., 23057., 15123.,
#        20454., 10165., 12561., 13057., 10490., 14793.,  9390., 21074.,
#        10206., 15290., 21776., 26800., 13790., 19421., 23471., 19380.,
#        19826., 21735., 38500., 20390., 29300., 17561., 19413., 23388.,
#        18132., 13595., 23719., 19743., 11290., 13016., 13300., 10700.,
#        10495., 20247., 27390., 27300.,  8390.,  6700., 38990.,  1300.,
#        33490., 19300., 17890., 26290., 17314., 38900.,  9380., 29800.,
#        18090., 14752., 19700., 14600., 14628., 12190., 23890., 10537.,
#        16400., 23490., 13099.,  9790., 13884., 13700., 30990., 41900.,
#        14421., 19290., 13842., 20290.,  8790.,  2490., 11790.,  5500.,
#        54990., 30190.,  6999., 20850.,  8650., 10950., 13347.,  6400.,
#        25890., 22890., 13690., 19360., 10300.,  4190., 14328., 17024.,
#         5490., 14190.,  9490., 20790.,  6290., 24290., 11690., 18400.,
#        41990., 21290., 17290., 17090., 32390., 12690., 22200., 20150.,
#        15790.,  4800., 20578., 12490., 16090., 20500.,  6200.,  4590.,
#        16440., 32490., 24490., 18890., 32892.,  8300., 13490.,  8504.,
#         5990.,  9200.,  8850., 16890.,  2690.,  7190., 18750.,  2300.,
#        18880., 47990., 61900., 23190.,  9290.,  4300., 20735.,  3990.,
#        19390., 19090., 14590., 18790., 18150., 24750., 10400.,  1800.,
#        41231., 16690.,  4490., 19950.,  7975., 28900., 17107., 21250.,
#         8250., 10250., 17150., 15390., 21190.,  5950.,  8700., 22290.,
#        23950., 31500., 16107., 10100.,  4990., 16818., 27933.,    nan])

# %%
data['KM'].unique()
# Out:
# array([47707., 57194., 66428., ..., 25215., 69773.,    nan], shape=(1151,))

# %%
data['Fuel'].unique()
# Out:
# array(['Diésel', 'Gasolina', 'Híbrido', 'Híbrido Enchufable', 'GLP',
#        'Eléctrico', 'GNC', nan], dtype=object)

# %%
copy_data=data.copy()

# %% [markdown]
# ### Problemas de calidad que deben solucionarse
#
# - Year: Tiene valores nan y comas que hay que eliminarse y

# %%
# Convertir la columna a valores numéricos (coerce convierte errores a NaN)
data['Year'] = pd.to_numeric(data['Year'], errors='coerce')

data = data.dropna(subset=['Year'])

data['Year'] = data['Year'].astype(int)

# %%
data['Year'].unique()
# Out:
# array([2022, 2019, 2017, 2016, 2020, 2018, 2015, 2021, 2013, 2011, 2014,
#        2023, 2012, 2006, 2010, 2008, 2005, 2009, 2004, 2007, 2024, 2002,
#        2003, 2000])

# %% [markdown]
# ### precio

# %%
data['Price'] = pd.to_numeric(data['Price'], errors='coerce')

data = data.dropna(subset=['Price'])

data['Price'] = data['Price'].astype(int)

# %%
data['Price'].unique()
# Out:
# array([15700, 24900, 17800,  9300, 21500, 20900, 15690, 13500, 23800,
#        37900, 14450, 26990, 27800, 34300, 14990, 19250,  9750, 23900,
#        12300, 19990, 15490, 12990,  8990, 24990, 21490, 16500, 18200,
#        21652, 22790, 15200, 16990, 25590, 12950, 19590, 10200, 11900,
#        16490, 15900, 15750, 27990, 23700, 15990, 15800, 14400, 20300,
#        29450, 11990, 12800,  8200, 25800, 34800, 15082, 26900, 21990,
#        13250, 22900, 17500, 10450, 18553, 39500, 19500, 22490, 13400,
#        13990, 18500, 10390, 13190, 12390, 13390, 30900, 14500, 20495,
#         4450, 12450,  6300, 14350,  3500, 20490, 11250, 57900,  2900,
#        15500, 21950,  9500, 26500, 29890, 12500, 16300, 44500, 28490,
#        16200, 24338, 15619,  8950, 46950, 20867,  4900, 16450, 14300,
#        20250,  3900, 18900, 17400, 21900, 20700, 15400,  7350, 20450,
#         7750, 16800, 23290,  9990, 32500,  9800, 11390, 46500,  9590,
#         4500, 15950,  9450,  2500, 24790, 22990, 12900, 25990, 17300,
#        17990,  3800, 10900,  5350,  5900, 11350, 21390,  8750, 12750,
#         8500, 11650,  7250, 34900,  8900, 22800, 20590, 37500, 13900,
#        14900, 13800, 22300, 14850, 48790, 12700, 19256, 16700, 10850,
#        34990,  8150, 27250, 26750, 23990, 13750, 26700, 14750, 15300,
#        33500, 18950, 25900, 11800, 18990, 21350, 29750, 34500, 10990,
#         5750, 13850, 24300, 24214, 28350, 31800, 22438, 14800, 17390,
#        25165, 20041, 27650, 23016, 53990,  8512, 23500, 19800, 10750,
#         7300, 28990, 20890, 17900, 22231, 10082, 10661, 12933, 20990,
#        22500, 11561, 14790, 17850, 15680, 19750, 22450, 17450,  6900,
#        12603, 25500, 21790, 15537, 17200, 16350,  7400, 14250,  8450,
#        19200, 13450, 16390,  9338, 14490, 29500, 14710, 14390, 18800,
#        28090, 21800, 15450,  9900, 17272,  6890, 20800, 18925, 14200,
#        19450,  7990, 11500, 28800, 40200, 11450, 10350, 61990, 11890,
#        14290, 18250,  9850, 13090,  6990, 11280, 14700, 32975,  8490,
#         8800, 34236, 14150, 21300,  7700, 24800, 40800, 12600, 19490,
#        11983, 27190, 28700, 16033, 18099, 32990, 16280, 29900, 27490,
#        36300, 41800, 13966,  6500,  7900, 39800, 17190, 11490,  9400,
#         7800, 10500, 16190, 17700, 18760, 25390, 16900,  8290, 12644,
#        44990, 12685, 24500, 10650, 13553, 17603,  4850, 50826, 18842,
#        25600,  5800, 13200,  8719, 13719, 15190, 25200, 45900, 22975,
#         9669, 13140, 29490,  7450, 16322, 20371, 13890, 19900, 18490,
#        22740, 10800, 18140, 14690, 16290, 28500, 13290, 26490,  7500,
#        25190, 49890, 21322, 14890, 15180, 11400, 18290, 23300, 12809,
#         9700, 40990, 20190, 25490, 16250, 31490, 21200, 10330, 22520,
#         8690, 22479, 16446, 10247, 18300, 36990, 23512, 18512,  6690,
#        18966, 26033, 20165, 21280, 19173, 12890, 21033, 11200, 11074,
#        45990, 15780, 16301, 10290, 22892, 22190, 12314, 17727, 25700,
#        23710,  3600, 21404,  5190, 18173, 23057, 15123, 20454, 10165,
#        12561, 13057, 10490, 14793,  9390, 21074, 10206, 15290, 21776,
#        26800, 13790, 19421, 23471, 19380, 19826, 21735, 38500, 20390,
#        29300, 17561, 19413, 23388, 18132, 13595, 23719, 19743, 11290,
#        13016, 13300, 10700, 10495, 20247, 27390, 27300,  8390,  6700,
#        38990,  1300, 33490, 19300, 17890, 26290, 17314, 38900,  9380,
#        29800, 18090, 14752, 19700, 14600, 14628, 12190, 23890, 10537,
#        16400, 23490, 13099,  9790, 13884, 13700, 30990, 41900, 14421,
#        19290, 13842, 20290,  8790,  2490, 11790,  5500, 54990, 30190,
#         6999, 20850,  8650, 10950, 13347,  6400, 25890, 22890, 13690,
#        19360, 10300,  4190, 14328, 17024,  5490, 14190,  9490, 20790,
#         6290, 24290, 11690, 18400, 41990, 21290, 17290, 17090, 32390,
#        12690, 22200, 20150, 15790,  4800, 20578, 12490, 16090, 20500,
#         6200,  4590, 16440, 32490, 24490, 18890, 32892,  8300, 13490,
#         8504,  5990,  9200,  8850, 16890,  2690,  7190, 18750,  2300,
#        18880, 47990, 61900, 23190,  9290,  4300, 20735,  3990, 19390,
#        19090, 14590, 18790, 18150, 24750, 10400,  1800, 41231, 16690,
#         4490, 19950,  7975, 28900, 17107, 21250,  8250, 10250, 17150,
#        15390, 21190,  5950,  8700, 22290, 23950, 31500, 16107, 10100,
#         4990, 16818, 27933])

# %%
data['KM'] = pd.to_numeric(data['KM'], errors='coerce')

data = data.dropna(subset=['KM'])



data['KM'].unique()
# Out:
# array([ 47707.,  57194.,  66428., ..., 108944.,  25215.,  69773.],
#       shape=(1150,))

# %%
data.isnull().sum()
# Out:
# Unnamed: 0         0
# Brand              0
# Name               0
# Sticker           25
# Year               0
# KM                 0
# Fuel               0
# CV                 0
# Transmission       0
# One_owner          0
# Location        1132
# Length             0
# Width              9
# Height             4
# Weight            20
# Trunk           1360
# Tank               0
# Vmax             158
# 0to100            26
# Consumption      182
# Emissions        879
# Keys_num           0
# Extras_num         0
# Price              0
# dtype: int64

# %%
data=data[~data['Fuel'].isna()]

# %%
data['Brand']=data['Brand'].str.split(" ").str.slice(0,3).str.join(' ')

# %%
data
# Out:
#       Unnamed: 0       Brand               Name Sticker  Year        KM  \
# 0              0        Opel         Opel Corsa       C  2022   47707.0
# 1              1     Peugeot     Peugeot Rifter       C  2019   57194.0
# 2              2     Renault     Renault Kadjar       C  2017   66428.0
# 3              3       Dacia      Dacia Sandero       C  2016   48430.0
# 4              4      Nissan     Nissan QASHQAI       C  2020   72209.0
# ...          ...         ...                ...     ...   ...       ...
# 5968        5968        Fiat         Fiat Linea       C  2008  293776.0
# 5969        5969  Volkswagen  Volkswagen Tiguan       C  2016   89142.0
# 5970        5970        Audi            Audi A4       B  2015  108944.0
# 5971        5971        Audi            Audi A3     ECO  2023   25215.0
# 5972        5972       Dacia       Dacia Duster       C  2018   69773.0
#
#           Fuel     CV Transmission One_owner  ...  Weight   Trunk  Tank  \
# 0       Diésel  102.0       MANUAL      True  ...  1165.0     NaN     -
# 1       Diésel  130.0         AUTO      True  ...  1430.0  1355.0     -
# 2       Diésel  110.0       MANUAL     False  ...  1380.0  1478.0     -
# 3     Gasolina   75.0       MANUAL      True  ...   941.0  1200.0     -
# 4     Gasolina  160.0         AUTO     False  ...  1315.0  1598.0     -
# ...        ...    ...          ...       ...  ...     ...     ...   ...
# 5968  Gasolina  120.0       MANUAL      True  ...  1200.0     NaN     -
# 5969  Gasolina  180.0         AUTO     False  ...  1645.0  1655.0     -
# 5970    Diésel  150.0       MANUAL     False  ...  1555.0     NaN     -
# 5971   Híbrido  150.0         AUTO      True  ...  1395.0  1200.0     -
# 5972    Diésel  109.0       MANUAL      True  ...  1280.0  1636.0     -
#
#        Vmax  0to100  Consumption Emissions  Keys_num  Extras_num  Price
# 0     188.0    10.2          4.1     107.0       1.0         5.0  15700
# 1     179.0     4.3        114.0       NaN       2.0         5.0  24900
# 2     182.0    11.9          3.8      99.0       2.0         5.0  17800
# 3     162.0    14.5          5.8     130.0       2.0         3.0   9300
# 4     198.0     9.9          6.9     156.0       2.0         5.0  21500
# ...     ...     ...          ...       ...       ...         ...    ...
# 5968  200.0     9.0          6.7     141.0       1.0         5.0   1800
# 5969  208.0     7.7          7.4     170.0       2.0         5.0  27490
# 5970  216.0     9.2          4.5     119.0       2.0         5.0  17700
# 5971  224.0     8.4          5.9     138.0       2.0         5.0  27933
# 5972  169.0    11.8          4.4     115.0       2.0         5.0  15990
#
# [5973 rows x 24 columns]

# %%
data.reset_index(drop=True)
# Out:
#       Unnamed: 0       Brand               Name Sticker  Year        KM  \
# 0              0        Opel         Opel Corsa       C  2022   47707.0
# 1              1     Peugeot     Peugeot Rifter       C  2019   57194.0
# 2              2     Renault     Renault Kadjar       C  2017   66428.0
# 3              3       Dacia      Dacia Sandero       C  2016   48430.0
# 4              4      Nissan     Nissan QASHQAI       C  2020   72209.0
# ...          ...         ...                ...     ...   ...       ...
# 5968        5968        Fiat         Fiat Linea       C  2008  293776.0
# 5969        5969  Volkswagen  Volkswagen Tiguan       C  2016   89142.0
# 5970        5970        Audi            Audi A4       B  2015  108944.0
# 5971        5971        Audi            Audi A3     ECO  2023   25215.0
# 5972        5972       Dacia       Dacia Duster       C  2018   69773.0
#
#           Fuel     CV Transmission One_owner  ...  Weight   Trunk  Tank  \
# 0       Diésel  102.0       MANUAL      True  ...  1165.0     NaN     -
# 1       Diésel  130.0         AUTO      True  ...  1430.0  1355.0     -
# 2       Diésel  110.0       MANUAL     False  ...  1380.0  1478.0     -
# 3     Gasolina   75.0       MANUAL      True  ...   941.0  1200.0     -
# 4     Gasolina  160.0         AUTO     False  ...  1315.0  1598.0     -
# ...        ...    ...          ...       ...  ...     ...     ...   ...
# 5968  Gasolina  120.0       MANUAL      True  ...  1200.0     NaN     -
# 5969  Gasolina  180.0         AUTO     False  ...  1645.0  1655.0     -
# 5970    Diésel  150.0       MANUAL     False  ...  1555.0     NaN     -
# 5971   Híbrido  150.0         AUTO      True  ...  1395.0  1200.0     -
# 5972    Diésel  109.0       MANUAL      True  ...  1280.0  1636.0     -
#
#        Vmax  0to100  Consumption Emissions  Keys_num  Extras_num  Price
# 0     188.0    10.2          4.1     107.0       1.0         5.0  15700
# 1     179.0     4.3        114.0       NaN       2.0         5.0  24900
# 2     182.0    11.9          3.8      99.0       2.0         5.0  17800
# 3     162.0    14.5          5.8     130.0       2.0         3.0   9300
# 4     198.0     9.9          6.9     156.0       2.0         5.0  21500
# ...     ...     ...          ...       ...       ...         ...    ...
# 5968  200.0     9.0          6.7     141.0       1.0         5.0   1800
# 5969  208.0     7.7          7.4     170.0       2.0         5.0  27490
# 5970  216.0     9.2          4.5     119.0       2.0         5.0  17700
# 5971  224.0     8.4          5.9     138.0       2.0         5.0  27933
# 5972  169.0    11.8          4.4     115.0       2.0         5.0  15990
#
# [5973 rows x 24 columns]

# %%
data.describe()
# Out:
#        Unnamed: 0         Year            KM           CV       Length  \
# count  5973.00000  5973.000000  5.973000e+03  5973.000000  5973.000000
# mean   2986.00000  2018.005190  8.169198e+04   133.583124     4.348507
# std    1724.40091     3.672202  5.705450e+04    48.986934     0.397570
# min       0.00000  2000.000000  5.000000e+00    20.000000     0.000000
# 25%    1493.00000  2016.000000  4.620100e+04   102.000000     4.140000
# 50%    2986.00000  2019.000000  7.483600e+04   125.000000     4.360000
# 75%    4479.00000  2021.000000  1.088270e+05   150.000000     4.520000
# max    5972.00000  2024.000000  1.116416e+06   498.000000     6.840000
#
#              Width       Height       Weight        Trunk         Vmax  \
# count  5964.000000  5969.000000  5953.000000  4613.000000  5815.000000
# mean      1.800342     1.566710  1387.058458  1334.004336   191.217713
# std       0.112896     0.184844   240.581446   375.613298    20.536075
# min       0.000000     0.000000   790.000000   406.000000     5.000000
# 25%       1.770000     1.450000  1210.000000  1143.000000   178.000000
# 50%       1.800000     1.520000  1361.000000  1251.000000   190.000000
# 75%       1.840000     1.650000  1513.000000  1503.000000   202.000000
# max       2.080000     3.080000  2425.000000  3500.000000   270.000000
#
#             0to100  Consumption    Emissions     Keys_num   Extras_num  \
# count  5947.000000  5791.000000  5094.000000  5973.000000  5973.000000
# mean     13.913889    19.747073   125.046133     1.770969     4.902059
# std      26.302284    48.845730    26.235877     0.420244     0.499783
# min       3.900000     1.000000    31.000000     1.000000     1.000000
# 25%       8.800000     4.500000   110.000000     2.000000     5.000000
# 50%      10.300000     5.300000   120.000000     2.000000     5.000000
# 75%      11.500000     6.200000   138.000000     2.000000     5.000000
# max     352.000000   602.000000   271.000000     2.000000     5.000000
#
#               Price
# count   5973.000000
# mean   17720.134941
# std     8087.514928
# min     1300.000000
# 25%    12490.000000
# 50%    16390.000000
# 75%    21490.000000
# max    61990.000000

# %%
data[data['Price']>60000]
# Out:
#       Unnamed: 0       Brand                   Name Sticker  Year       KM  \
# 822          822     Porsche          Porsche Macan       C  2020  94287.0
# 1002        1002     Porsche          Porsche Macan       C  2020  94287.0
# 1282        1282     Porsche          Porsche Macan       C  2020  94287.0
# 2400        2400  Volkswagen  Volkswagen California       C  2024   1414.0
# 2779        2779  Volkswagen  Volkswagen California       C  2024   1414.0
# 3238        3238  Volkswagen  Volkswagen California       C  2024   1414.0
# 3614        3614  Volkswagen  Volkswagen California       C  2024   1414.0
# 4170        4170  Volkswagen  Volkswagen California       C  2024   1414.0
# 4566        4566  Volkswagen  Volkswagen California       C  2024   1414.0
# 4789        4789     Renault         Renault Master       C  2023  16670.0
# 5162        5162  Volkswagen  Volkswagen California       C  2024   1414.0
# 5385        5385     Renault         Renault Master       C  2023  16670.0
# 5638        5638  Volkswagen  Volkswagen California       C  2024   1414.0
# 5861        5861     Renault         Renault Master       C  2023  16670.0
#
#           Fuel     CV Transmission One_owner  ...  Weight   Trunk  Tank  \
# 822   Gasolina  354.0         AUTO      True  ...  1940.0  1500.0     -
# 1002  Gasolina  354.0         AUTO      True  ...  1940.0  1500.0     -
# 1282  Gasolina  354.0         AUTO      True  ...  1940.0  1500.0     -
# 2400    Diésel  150.0       MANUAL      True  ...  2411.0     NaN     -
# 2779    Diésel  150.0       MANUAL      True  ...  2411.0     NaN     -
# 3238    Diésel  150.0       MANUAL      True  ...  2411.0     NaN     -
# 3614    Diésel  150.0       MANUAL      True  ...  2411.0     NaN     -
# 4170    Diésel  150.0       MANUAL      True  ...  2411.0     NaN     -
# 4566    Diésel  150.0       MANUAL      True  ...  2411.0     NaN     -
# 4789    Diésel  145.0       MANUAL     False  ...     NaN     NaN     -
# 5162    Diésel  150.0       MANUAL      True  ...  2411.0     NaN     -
# 5385    Diésel  145.0       MANUAL     False  ...     NaN     NaN     -
# 5638    Diésel  150.0       MANUAL      True  ...  2411.0     NaN     -
# 5861    Diésel  145.0       MANUAL     False  ...     NaN     NaN     -
#
#        Vmax  0to100  Consumption Emissions  Keys_num  Extras_num  Price
# 822   254.0     5.3         10.7     243.0       2.0         5.0  61990
# 1002  254.0     5.3         10.7     243.0       2.0         5.0  61990
# 1282  254.0     5.3         10.7     243.0       2.0         5.0  61990
# 2400    NaN   192.0          NaN       NaN       2.0         5.0  61990
# 2779    NaN   192.0          NaN       NaN       2.0         5.0  61990
# 3238    NaN   192.0          NaN       NaN       2.0         5.0  61990
# 3614    NaN   192.0          NaN       NaN       2.0         5.0  61990
# 4170    NaN   192.0          NaN       NaN       2.0         5.0  61990
# 4566    NaN   192.0          NaN       NaN       2.0         5.0  61990
# 4789    NaN     NaN          NaN       NaN       1.0         5.0  61900
# 5162    NaN   192.0          NaN       NaN       2.0         5.0  61990
# 5385    NaN     NaN          NaN       NaN       1.0         5.0  61900
# 5638    NaN   192.0          NaN       NaN       2.0         5.0  61990
# 5861    NaN     NaN          NaN       NaN       1.0         5.0  61900
#
# [14 rows x 24 columns]

# %%
data=data[data['Price']<60000].reset_index(drop=True)

# %%
data.shape
# Out:
# (5959, 24)

# %% [markdown]
# ### model

# %%
X=data.drop(columns='Price')
y=data['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %% [markdown]
# ### Creación de un objeto OneHotEncoder para contener todas las categorías posibles

# %%
ohe=OneHotEncoder()
ohe.fit(X[['Name','Brand','Fuel']])
# Out:
# OneHotEncoder()

# %% [markdown]
# ### Creación de un transformador de columnas para transformar columnas categóricas

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Name','Brand','Fuel']),
                                    remainder='passthrough')

# %% [markdown]
# ### Modelo de regresión lineal

# %%
lr=LinearRegression()

# %% [markdown]
# ### haciendo una pipeline

# %%
pipe=make_pipeline(column_trans,lr)

# %% [markdown]
# ### Montaje del model

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\luisg\Desktop\js_anthony\Coches_segunda_mano_ia\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py in ?(self, Xs, n_samples)
#    1133                 ]
#    1134             except ValueError as e:
# -> 1135                 raise ValueError(
#    1136                     "For a sparse output, all columns should "
#
# c:\Users\luisg\Desktop\js_anthony\Coches_segunda_mano_ia\.venv\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                 else:
#    1053                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1054             except ComplexWarning as complex_warning:
#    1055                 raise ValueError(
#
# c:\Users\luisg\Desktop\js_anthony\Coches_segunda_mano_ia\.venv\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     755             array = numpy.array(array, order=order, dtype=dtype)
#     756         else:
# --> 757             array = numpy.asarray(array, order=order, dtype=dtype)
#     758
#
# c:\Users\luisg\Desktop\js_anthony\Coches_segunda_mano_ia\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2166         if copy is None:
#    2167             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2168             arr = np.asarray(values, dtype=dtype)
#    2169         else:
#
# ValueError: could not convert string to float: 'C'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 pipe.fit(X_train,y_train)
#
# File c:\Users\luisg\Desktop\js_anthony\Coches_segunda_mano_ia\.venv\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\luisg\Desktop\js_anthony\Coches_segunda_mano_ia\.venv\Lib\site-packages\sklearn\pipeline.py:655, in Pipeline.fit(self, X, y, **params)
#     648     raise ValueError(
#     649         "The `transform_input` parameter can only be set if metadata "
#     650         "routing is enabled. You can enable metadata routing using "
#     651         "`sklearn.set_config(enable_metadata_routing=True)`."
#     652     )
#     654 routed_params = self._check_method_params(method="fit", props=params)
# --> 655 Xt = self._fit(X, y, routed_params, raw_params=params)
#     656 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     657     if self._final_estimator != "passthrough":
#
# File c:\Users\luisg\Desktop\js_anthony\Coches_segunda_mano_ia\.venv\Lib\site-packages\sklearn\pipeline.py:589, in Pipeline._fit(self, X, y, routed_params, raw_params)
#     582 # Fit or load from cache the current transformer
#     583 step_params = self._get_metadata_for_step(
#     584     step_idx=step_idx,
#     585     step_params=routed_params[name],
#     586     all_params=raw_params,
#     587 )
# --> 589 X, fitted_transformer = fit_transform_one_cached(
#     590     cloned_transformer,
#     591     X,
#     592     y,
#     593     weight=None,
#     594     message_clsname="Pipeline",
#     595     message=self._log_message(step_idx),
#     596     params=step_params,
#     597 )
#     598 # Replace the transformer of the step with the fitted
#     599 # transformer. This is necessary when loading the transformer
#     600 # from the cache.
#     601 self.steps[step_idx] = (name, fitted_transformer)
#
# File c:\Users\luisg\Desktop\js_anthony\Coches_segunda_mano_ia\.venv\Lib\site-packages\joblib\memory.py:326, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     325 def __call__(self, *args, **kwargs):
# --> 326     return self.func(*args, **kwargs)
#
# File c:\Users\luisg\Desktop\js_anthony\Coches_segunda_mano_ia\.venv\Lib\site-packages\sklearn\pipeline.py:1540, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1538 with _print_elapsed_time(message_clsname, message):
#    1539     if hasattr(transformer, "fit_transform"):
# -> 1540         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1541     else:
#    1542         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1543             X, **params.get("transform", {})
#    1544         )
#
# File c:\Users\luisg\Desktop\js_anthony\Coches_segunda_mano_ia\.venv\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\luisg\Desktop\js_anthony\Coches_segunda_mano_ia\.venv\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\luisg\Desktop\js_anthony\Coches_segunda_mano_ia\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:1026, in ColumnTransformer.fit_transform(self, X, y, **params)
#    1023 self._validate_output(Xs)
#    1024 self._record_output_indices(Xs)
# -> 1026 return self._hstack(list(Xs), n_samples=n_samples)
#
# File c:\Users\luisg\Desktop\js_anthony\Coches_segunda_mano_ia\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:1135, in ColumnTransformer._hstack(self, Xs, n_samples)
#    1130         converted_Xs = [
#    1131             check_array(X, accept_sparse=True, ensure_all_finite=False)
#    1132             for X in Xs
#    1133         ]
#    1134     except ValueError as e:
# -> 1135         raise ValueError(
#    1136             "For a sparse output, all columns should "
#    1137             "be a numeric or convertible to a numeric."
#    1138         ) from e
#    1140     return sparse.hstack(converted_Xs).tocsr()
#    1141 else:
#
# ValueError: For a sparse output, all columns should be a numeric or convertible to a numeric.
